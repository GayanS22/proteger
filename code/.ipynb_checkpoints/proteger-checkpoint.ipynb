# %%
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt

# %%
IMAGE_SIZE = 256
BATCH_SIZE = 32
CHANNELS=3
EPOCHS=30

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "Training_data_set/",
    shuffle=True,
    image_size = (IMAGE_SIZE,IMAGE_SIZE),
    batch_size = BATCH_SIZE
)
# Out:
# Found 11207 files belonging to 38 classes.

# %%
class_names = dataset.class_names
class_names
# Out:
# ['Apple___Apple_scab',
#  'Apple___Black_rot',
#  'Apple___Cedar_apple_rust',
#  'Apple___healthy',
#  'Blueberry___healthy',
#  'Cherry___Powdery_mildew',
#  'Cherry___healthy',
#  'Corn___Cercospora_leaf_spot Gray_leaf_spot',
#  'Corn___Common_rust',
#  'Corn___Northern_Leaf_Blight',
#  'Corn___healthy',
#  'Grape___Black_rot',
#  'Grape___Esca_Black_Measles',
#  'Grape___Leaf_blight',
#  'Grape___healthy',
#  'Orange___Citrus_greening',
#  'Peach___Bacterial_spot',
#  'Peach___healthy',
#  'Pepper___Bacterial_spot',
#  'Pepper___healthy',
#  'Potato___Early_blight',
#  'Potato___Late_blight',
#  'Potato___healthy',
#  'Raspberry___healthy',
#  'Soybean___healthy',
#  'Squash___Powdery_mildew',
#  'Strawberry___Leaf_scorch',
#  'Strawberry___healthy',
#  'Tomato___Bacterial_spot',
#  'Tomato___Early_blight',
#  'Tomato___Late_blight',
#  'Tomato___Leaf_Mold',
#  'Tomato___Septoria_leaf_spot',
#  'Tomato___Spider_mites Two-spotted_spider_mite',
#  'Tomato___Target_Spot',
#  'Tomato___Tomato_Yellow_Leaf_Curl_Virus',
#  'Tomato___Tomato_mosaic_virus',
#  'Tomato___healthy']

# %%
def get_dataset_partitions_tf(ds, train_split=0.8, val_split=0.1, test_split=0.1, shuffle=True, shuffle_size=10000):
    ds_size = len(ds)
    
    if shuffle:
        ds = ds.shuffle(shuffle_size, seed=12)
        
    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)
    
    train_ds = ds.take(train_size)
    
    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size).skip(val_size)
    
    return train_ds, val_ds, test_ds

# %%
train_ds, val_ds, test_ds = get_dataset_partitions_tf(dataset)

# %%
len(train_ds)
# Out:
# 280

# %%
len(val_ds)
# Out:
# 35

# %%
len(test_ds)
# Out:
# 36

# %%
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
resize_and_rescale = tf.keras.Sequential([
    layers.experimental.preprocessing.Resizing(IMAGE_SIZE, IMAGE_SIZE),
    layers.experimental.preprocessing.Rescaling(1.0/255)
])

# %%
pretrained_model = tf.keras.applications.xception.Xception(include_top=False,
                                                           input_shape=(256,256,3),
                                                           weights="imagenet",
                                                           pooling='max')

for layer in pretrained_model.layers:
        layer.trainable=False

# %%
input_shape = (BATCH_SIZE, IMAGE_SIZE, IMAGE_SIZE, CHANNELS)
model = tf.keras.models.Sequential()

model.add(resize_and_rescale)

model.add(pretrained_model)

model.add(tf.keras.layers.Flatten())

model.add(tf.keras.layers.Dense(38, activation='softmax'))

model.build(input_shape=input_shape)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential (Sequential)      (32, 256, 256, 3)         0
# _________________________________________________________________
# xception (Functional)        (None, 2048)              20861480
# _________________________________________________________________
# flatten (Flatten)            (32, 2048)                0
# _________________________________________________________________
# dense (Dense)                (32, 38)                  77862
# =================================================================
# Total params: 20,939,342
# Trainable params: 77,862
# Non-trainable params: 20,861,480
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_ds,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=1,
    validation_data=val_ds
)
# Out:
# Epoch 1/30
# 280/280 [==============================] - 1053s 3s/step - loss: 1.1798 - accuracy: 0.6749 - val_loss: 0.4755 - val_accuracy: 0.8667
# Epoch 2/30
# 280/280 [==============================] - 746s 3s/step - loss: 0.4364 - accuracy: 0.8670 - val_loss: 0.3666 - val_accuracy: 0.8886
# Epoch 3/30
# 280/280 [==============================] - 769s 3s/step - loss: 0.3012 - accuracy: 0.9048 - val_loss: 0.2415 - val_accuracy: 0.9279
# Epoch 4/30
# 280/280 [==============================] - 2669s 10s/step - loss: 0.2258 - accuracy: 0.9324 - val_loss: 0.2213 - val_accuracy: 0.9397
# Epoch 5/30
# 280/280 [==============================] - 730s 3s/step - loss: 0.1721 - accuracy: 0.9499 - val_loss: 0.2270 - val_accuracy: 0.9416
# Epoch 6/30
# 280/280 [==============================] - 750s 3s/step - loss: 0.1334 - accuracy: 0.9619 - val_loss: 0.1751 - val_accuracy: 0.9534
# Epoch 7/30
# 280/280 [==============================] - 759s 3s/step - loss: 0.1026 - accuracy: 0.9725 - val_loss: 0.1419 - val_accuracy: 0.9653
# Epoch 8/30
# 280/280 [==============================] - 739s 3s/step - loss: 0.0801 - accuracy: 0.9821 - val_loss: 0.1228 - val_accuracy: 0.9735
# Epoch 9/30
# 280/280 [==============================] - 745s 3s/step - loss: 0.0687 - accuracy: 0.9860 - val_loss: 0.1237 - val_accuracy: 0.9653
# Epoch 10/30
# 280/280 [==============================] - 751s 3s/step - loss: 0.0615 - accuracy: 0.9872 - val_loss: 0.1124 - val_accuracy: 0.9735
# Epoch 11/30
# 280/280 [==============================] - 754s 3s/step - loss: 0.0475 - accuracy: 0.9915 - val_loss: 0.0996 - val_accuracy: 0.9790
# Epoch 12/30
# 280/280 [==============================] - 746s 3s/step - loss: 0.0391 - accuracy: 0.9946 - val_loss: 0.1064 - val_accuracy: 0.9726
# Epoch 13/30
# 280/280 [==============================] - 720s 3s/step - loss: 0.0358 - accuracy: 0.9940 - val_loss: 0.0974 - val_accuracy: 0.9772
# Epoch 14/30
# 280/280 [==============================] - 721s 3s/step - loss: 0.0246 - accuracy: 0.9985 - val_loss: 0.0994 - val_accuracy: 0.9772
# Epoch 15/30
# 280/280 [==============================] - 751s 3s/step - loss: 0.0306 - accuracy: 0.9942 - val_loss: 0.1602 - val_accuracy: 0.9571
# Epoch 16/30
# 280/280 [==============================] - 743s 3s/step - loss: 0.0682 - accuracy: 0.9811 - val_loss: 0.1475 - val_accuracy: 0.9699
# Epoch 17/30
# 280/280 [==============================] - 728s 3s/step - loss: 0.0375 - accuracy: 0.9923 - val_loss: 0.1213 - val_accuracy: 0.9717
# Epoch 18/30
# 280/280 [==============================] - 723s 3s/step - loss: 0.0277 - accuracy: 0.9951 - val_loss: 0.1212 - val_accuracy: 0.9708
# Epoch 19/30
# 280/280 [==============================] - 735s 3s/step - loss: 0.0132 - accuracy: 0.9985 - val_loss: 0.1046 - val_accuracy: 0.9781
# Epoch 20/30
# 280/280 [==============================] - 739s 3s/step - loss: 0.0088 - accuracy: 0.9998 - val_loss: 0.0963 - val_accuracy: 0.9763
# Epoch 21/30
# 280/280 [==============================] - 720s 3s/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.0966 - val_accuracy: 0.9753
# Epoch 22/30
# 280/280 [==============================] - 725s 3s/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.0939 - val_accuracy: 0.9790
# Epoch 23/30
# 280/280 [==============================] - 725s 3s/step - loss: 0.0065 - accuracy: 0.9998 - val_loss: 0.1020 - val_accuracy: 0.9799
# Epoch 24/30
# 280/280 [==============================] - 728s 3s/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.1052 - val_accuracy: 0.9763
# Epoch 25/30
# 280/280 [==============================] - 721s 3s/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.0962 - val_accuracy: 0.9781
# Epoch 26/30
# 280/280 [==============================] - 729s 3s/step - loss: 0.0059 - accuracy: 0.9999 - val_loss: 0.1023 - val_accuracy: 0.9799
# Epoch 27/30
# 280/280 [==============================] - 723s 3s/step - loss: 0.1810 - accuracy: 0.9506 - val_loss: 0.2358 - val_accuracy: 0.9342
# Epoch 28/30
# 280/280 [==============================] - 726s 3s/step - loss: 0.0445 - accuracy: 0.9874 - val_loss: 0.1075 - val_accuracy: 0.9790
# Epoch 29/30
# 280/280 [==============================] - 723s 3s/step - loss: 0.0074 - accuracy: 0.9993 - val_loss: 0.1057 - val_accuracy: 0.9763
# Epoch 30/30
# 280/280 [==============================] - 727s 3s/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.0949 - val_accuracy: 0.9799

# %%
scores = model.evaluate(test_ds)
# Out:
# 36/36 [==============================] - 320s 2s/step - loss: 0.0685 - accuracy: 0.9818

# %%
scores
# Out:
# [0.06853379309177399, 0.9817708134651184]

# %%
history.history['accuracy']
# Out:
# [0.6748740673065186,
#  0.8670397400856018,
#  0.9047565460205078,
#  0.932400643825531,
#  0.9498600959777832,
#  0.9619473814964294,
#  0.972467839717865,
#  0.9820929169654846,
#  0.9860100746154785,
#  0.9872412085533142,
#  0.9914941191673279,
#  0.9946278929710388,
#  0.9939563274383545,
#  0.9985450506210327,
#  0.9941802024841309,
#  0.9810855984687805,
#  0.9922775626182556,
#  0.995075523853302,
#  0.9985450506210327,
#  0.9997761845588684,
#  1.0,
#  1.0,
#  0.9997761845588684,
#  1.0,
#  1.0,
#  0.9998880624771118,
#  0.9506435394287109,
#  0.9873530864715576,
#  0.9993284940719604,
#  1.0]

# %%
history.params
# Out:
# {'verbose': 1, 'epochs': 30, 'steps': 280}

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(range(EPOCHS), acc, label='Training Accuracy')
plt.plot(range(EPOCHS), val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(range(EPOCHS), loss, label='Training Loss')
plt.plot(range(EPOCHS), val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
model.save("../proteger-model.h5")

# %%
import numpy as np
for images_batch, labels_batch in test_ds.take(1):
    
    first_image = images_batch[0].numpy().astype('uint8')
    first_label = labels_batch[0].numpy()
    
    print("first image to predict")
    plt.imshow(first_image)
    print("actual label:",class_names[first_label])
    
    batch_prediction = model.predict(images_batch)
    print("predicted label:",class_names[np.argmax(batch_prediction[0])])
# Out:
# first image to predict
# actual label: Potato___healthy
# predicted label: Potato___healthy

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    img_array = tf.expand_dims(img_array, 0)

    predictions = model.predict(img_array)

    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
plt.figure(figsize=(15, 15))
for images, labels in test_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        
        predicted_class, confidence = predict(model, images[i].numpy())
        actual_class = class_names[labels[i]] 
        
        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")
        
        plt.axis("off")
